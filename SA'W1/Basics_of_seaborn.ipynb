# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
x=[10,20,30,40]
y=[0,15,10,25]
plt.plot(x,y)
plt.show()

# %%
sns.set()
plt.plot(x,y)
sns.set_style("white")
plt.plot(x,y);

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.0'

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
cars=sns.load_dataset('mpg')

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.dropna(inplace=True)
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year',y='mpg',col='origin',hue='cylinders',data=cars);

# %%
# leant about the kernel density function
sns.kdeplot(cars.horsepower,fill=True);
# bandwidth bw mattars lot

# %%
sns.kdeplot(cars.horsepower,cumulative=True);

# %%
# Bivariate 2D kde plot
# sns.kdeplot(cars.horsepower,cars.mpg,n_levels=20); having some error
# Use the seaborn cheat sheet to plot differnet kind of plots
# such as Displot, Boxplot, Violinplot, sactterplot, Seabornline plot,
# heatmap , pariplot & Barplot
# Use different sources according to need

# %%
sns.histplot(cars.weight,kde=True);
# we can use that instead of using this sns.distplot(cars.weight);
